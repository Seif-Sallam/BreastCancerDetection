# %%
# Testing that the machine recognizes the GPU
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# 2022-11-08 09:23:35.520258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:23:35.521372: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:23:35.864341: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:23:35.865212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:23:35.865965: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:23:35.866775: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import pandas as pd
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
import seaborn as sns
import os
from os.path import isfile
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras import utils
import itertools
import shutil
np.random.seed(42)
from PIL import Image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.6.4
# 2.6.0

# %%
# gpu_options = tf.compat.v1.GPUOptions(allow_growth=True, per_process_gpu_memory_fraction=0.5)
# sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

current_dir = os.getcwd()
print(current_dir)
# Out:
# /kaggle/working

# %%
pos_data = []
neg_data = []

if True:
    cur_dir = os.getcwd()
    patient_dir = "/kaggle/input/breast-histopathology-images/"
    patient_list = os.listdir(patient_dir)

    for patient in patient_list:

      try:

        path_0 = patient_dir + str(patient) + '/0'
        path_1 = patient_dir + str(patient) + '/1'
        
        # create a list of all files in folder 0
        file_list_0 = os.listdir(path_0)
        # create a list of list all file in folder 1
        file_list_1 = os.listdir(path_1)

        # move the 0 images to all_images_dir
        for fname in file_list_0:
            # source path to image
            src = os.path.join(path_0, fname)
            if os.path.isfile(src):
              neg_data.append(src)

        # move the 1 images to all_images_dir
        for fname in file_list_1:

            # source path to image
            src = os.path.join(path_1, fname)
            if os.path.isfile(src):
              pos_data.append(src)

      except:
        print(patient + " cannot be added properly")
else:
    print("Data already exists. Skipped copying")

print(f"Total: {len(neg_data) + len(pos_data)}")
print(f"Negative Data: {len(neg_data)}")
print(f"Positive Data: {len(pos_data)}")
# Out:
# IDC_regular_ps50_idx5 cannot be added properly
# Total: 277524
# Negative Data: 198738
# Positive Data: 78786

# %%
###### Mostly, taken from the other author's notebook. ######

# Create a dataframe containing all the information

# image_list_1 = os.listdir(f'{all_images_dir}/1')
# df_data_1 = pd.DataFrame(image_list_1, columns=['image_id'])

# image_list_0 = os.listdir(f'{all_images_dir}/0')
# df_data_0 = pd.DataFrame(image_list_0, columns=['image_id'])

df_data_1 = pd.DataFrame(pos_data, columns=['image_id'])
df_data_0 = pd.DataFrame(neg_data, columns=['image_id'])

df_data = pd.concat([df_data_1, df_data_0])

# %%
# Validating that the data now exists in the dataframe
df_data.head()
# Out:
#                                             image_id
# 0  /kaggle/input/breast-histopathology-images/102...
# 1  /kaggle/input/breast-histopathology-images/102...
# 2  /kaggle/input/breast-histopathology-images/102...
# 3  /kaggle/input/breast-histopathology-images/102...
# 4  /kaggle/input/breast-histopathology-images/102...

# %%
###### Mostly, taken from the other author's notebook. ######

# Define Helper Functions

# Each file name has this format:
# '14211_idx5_x2401_y1301_class1.png'

prefix = "/kaggle/input/breast-histopathology-images/"
def extract_patient_id(x):
    st = x[len(prefix):]
    # split into a list
    a = st.split('/')
    # the id is the first index in the list
    patient_id = a[0]
    
    return patient_id

def extract_target(x):
    st = x[len(prefix):]
    # split into a list
    a = st.split('_')
    # the target is part of the string in index 4
    b = a[4]
    # the ytarget i.e. 1 or 2 is the 5th index of the string --> class1
    target = b[5]
    
    return target

# extract the patient id

# create a new column called 'patient_id'
df_data['patient_id'] = df_data['image_id'].apply(extract_patient_id)
# create a new column called 'target'
df_data['target'] = df_data['image_id'].apply(extract_target)

df_data.head()
# Out:
#                                             image_id patient_id target
# 0  /kaggle/input/breast-histopathology-images/102...      10295      1
# 1  /kaggle/input/breast-histopathology-images/102...      10295      1
# 2  /kaggle/input/breast-histopathology-images/102...      10295      1
# 3  /kaggle/input/breast-histopathology-images/102...      10295      1
# 4  /kaggle/input/breast-histopathology-images/102...      10295      1

# %%
# Showing the class distribution of the dataset, We find that the negative is way more than the positives.
sns.countplot(x=df_data.target).set_title("Class Distributions")
# Out:
# Text(0.5, 1.0, 'Class Distributions')

# %%
from sklearn.model_selection import train_test_split

y = df_data['target']

_, df_test = train_test_split(df_data, test_size=0.03603, random_state=42, stratify=y)

_, df_val = train_test_split(df_data, test_size=0.0036025, random_state=42, stratify=y)

print('Valid:', df_val.shape[0])
print('Test:', df_test.shape[0])
# Out:
# Valid: 1000
# Test: 10000

# %%
sns.countplot(x=df_val['target']).set_title('Valid Class Distributions')
# Out:
# Text(0.5, 1.0, 'Valid Class Distributions')

# %%
sns.countplot(x=df_test['target']).set_title('Test Class Distributions')
# Out:
# Text(0.5, 1.0, 'Test Class Distributions')

# %%
# Improved the speed of the identification through using a dictionary... Dramatically.
val_dict = df_val.set_index('image_id').T.to_dict('list')
test_dict = df_test.set_index('image_id').T.to_dict('list')

def identify_train_val_and_test_rows(x):
    if str(x) in val_dict:
        return 'val'
    elif str(x) in test_dict:
        return 'test'
    else:
        return 'train'

# create a new colum that is a copy of the image_id column
df_data['train_or_val_or_test'] = df_data['image_id']
# apply the function to this new column
df_data['train_or_val_or_test'] = df_data['train_or_val_or_test'].apply(identify_train_val_and_test_rows)
   
# filter out train rows
df_train = df_data[df_data['train_or_val_or_test'] == 'train']

print('Train:', len(df_train))
print('Valid:', len(df_val))
print('Test:', len(df_test))
df_data.head()
# Out:
# Train: 267524
# Valid: 1000
# Test: 10000
#                                             image_id patient_id target  \
# 0  /kaggle/input/breast-histopathology-images/102...      10295      1
# 1  /kaggle/input/breast-histopathology-images/102...      10295      1
# 2  /kaggle/input/breast-histopathology-images/102...      10295      1
# 3  /kaggle/input/breast-histopathology-images/102...      10295      1
# 4  /kaggle/input/breast-histopathology-images/102...      10295      1
#
#   train_or_val_or_test
# 0                train
# 1                train
# 2                train
# 3                train
# 4                train

# %%
sns.countplot(x=df_train['target']).set_title('Train Class Distributions')
# Out:
# Text(0.5, 1.0, 'Train Class Distributions')

# %%
# Set the image_id as the index in df_data
df_data.set_index('image_id', inplace=True)
df_data.head()
# Out:
#                                                    patient_id target  \
# image_id
# /kaggle/input/breast-histopathology-images/1029...      10295      1
# /kaggle/input/breast-histopathology-images/1029...      10295      1
# /kaggle/input/breast-histopathology-images/1029...      10295      1
# /kaggle/input/breast-histopathology-images/1029...      10295      1
# /kaggle/input/breast-histopathology-images/1029...      10295      1
#
#                                                    train_or_val_or_test
# image_id
# /kaggle/input/breast-histopathology-images/1029...                train
# /kaggle/input/breast-histopathology-images/1029...                train
# /kaggle/input/breast-histopathology-images/1029...                train
# /kaggle/input/breast-histopathology-images/1029...                train
# /kaggle/input/breast-histopathology-images/1029...                train

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

num_train_samples = len(df_train)
num_val_samples = len(df_val)

train_batch_size = 500
val_batch_size = 500

train_steps = np.ceil(num_train_samples / train_batch_size)
val_steps = np.ceil(num_val_samples / val_batch_size)

# %%
datagen = ImageDataGenerator(preprocessing_function=keras.applications.inception_v3.preprocess_input, 
                             horizontal_flip=True,
                             vertical_flip=True)
image_size=100

train_batches_bench = datagen.flow_from_dataframe(df_train, 
                                                  target_size=(image_size, image_size),
                                                  batch_size=train_batch_size,
                                                  x_col='image_id',
                                                  y_col='target')

valid_batches_bench = datagen.flow_from_dataframe(df_val, 
                                                  target_size=(image_size, image_size),
                                                  batch_size=val_batch_size,
                                                  x_col='image_id',
                                                  y_col='target')

test_batches_bench = datagen.flow_from_dataframe(df_test,
                                                 target_size=(image_size, image_size),
                                                 batch_size=1,
                                                 shuffle=False,
                                                 x_col='image_id',
                                                 y_col='target')
# Out:
# Found 267524 validated image filenames belonging to 2 classes.
# Found 1000 validated image filenames belonging to 2 classes.
# Found 10000 validated image filenames belonging to 2 classes.

# %%
from tensorflow.keras.applications.vgg19 import VGG19
vgg = tf.keras.applications.vgg19.VGG19(
    include_top=False,			# We do not want the classifier on top of the VGG19, we will use our own classifier
    weights=None,			# We want the imagenet weights
    input_shape=(image_size, image_size, 3)	# The input shape is 100, 100, 3 (RGB)
)
# Out:
# 2022-11-08 09:31:44.636488: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-08 09:31:44.897264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:44.898093: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:44.898811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:44.899600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:44.900326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:44.901078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:49.774497: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:49.775386: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:49.776176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:49.776865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:49.777548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:49.778270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-08 09:31:49.783490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 09:31:49.784232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
x = tf.keras.layers.Flatten()(vgg.output)  # One flatten layer
prediction = tf.keras.layers.Dense(2, activation='softmax')(x) # one softmax layer
model = tf.keras.Model(inputs=vgg.input, outputs=prediction)   # Final Model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 9218
# =================================================================
# Total params: 20,033,602
# Trainable params: 20,033,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
# This needs to be checked
# We need to know which data to be added exactly. We want the Image Data Generator function but without any agumentation (for now)
# did not have time to check exactly how. 
# Try to compare with the paper stuff. Hopefully we will be able to find something.
from tensorflow.keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint(filepath='breast_histopathology_baseline_NOAUG.hdf5', verbose=1, save_best_only=True)

class_weights={
    0: 1.0, # negative
    1: 1.0, # postive 
    # make model more sensitive to positive class if necessary
}

# using RMSProp optimizer as it  is the best optimizers according to this paper:
# https://www.sciencedirect.com/science/article/pii/S2214785321013316
model.compile(loss='categorical_crossentropy', optimizer='RMSProp', metrics=['accuracy']) 
history = model.fit(train_batches_bench, 
					steps_per_epoch=train_steps, 
					class_weight=class_weights,
					validation_data=valid_batches_bench,
					validation_steps=val_steps,
					callbacks=[model_checkpoint], 
					epochs=30, 
					verbose=1)
# Out:
# 2022-11-08 09:31:53.710843: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/30
# 2022-11-08 09:32:00.427726: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 536/536 [==============================] - 1702s 3s/step - loss: 66.5852 - accuracy: 0.7132 - val_loss: 0.5000 - val_accuracy: 0.7160
#
# Epoch 00001: val_loss improved from inf to 0.49999, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 2/30
# 536/536 [==============================] - 943s 2s/step - loss: 0.4476 - accuracy: 0.8029 - val_loss: 0.3820 - val_accuracy: 0.8320
#
# Epoch 00002: val_loss improved from 0.49999 to 0.38197, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 3/30
# 536/536 [==============================] - 948s 2s/step - loss: 0.3756 - accuracy: 0.8422 - val_loss: 0.3624 - val_accuracy: 0.8470
#
# Epoch 00003: val_loss improved from 0.38197 to 0.36242, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 4/30
# 536/536 [==============================] - 948s 2s/step - loss: 0.3563 - accuracy: 0.8526 - val_loss: 0.3827 - val_accuracy: 0.8360
#
# Epoch 00004: val_loss did not improve from 0.36242
# Epoch 5/30
# 536/536 [==============================] - 949s 2s/step - loss: 0.3319 - accuracy: 0.8599 - val_loss: 0.3422 - val_accuracy: 0.8630
#
# Epoch 00005: val_loss improved from 0.36242 to 0.34221, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 6/30
# 536/536 [==============================] - 951s 2s/step - loss: 0.3283 - accuracy: 0.8634 - val_loss: 0.3173 - val_accuracy: 0.8610
#
# Epoch 00006: val_loss improved from 0.34221 to 0.31729, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 7/30
# 536/536 [==============================] - 950s 2s/step - loss: 0.3121 - accuracy: 0.8684 - val_loss: 0.2974 - val_accuracy: 0.8680
#
# Epoch 00007: val_loss improved from 0.31729 to 0.29738, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 8/30
# 536/536 [==============================] - 950s 2s/step - loss: 0.3119 - accuracy: 0.8687 - val_loss: 0.3319 - val_accuracy: 0.8680
#
# Epoch 00008: val_loss did not improve from 0.29738
# Epoch 9/30
# 536/536 [==============================] - 951s 2s/step - loss: 0.3157 - accuracy: 0.8724 - val_loss: 0.2921 - val_accuracy: 0.8720
#
# Epoch 00009: val_loss improved from 0.29738 to 0.29213, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 10/30
# 536/536 [==============================] - 953s 2s/step - loss: 0.3172 - accuracy: 0.8723 - val_loss: 0.4397 - val_accuracy: 0.8590
#
# Epoch 00010: val_loss did not improve from 0.29213
# Epoch 11/30
# 536/536 [==============================] - 952s 2s/step - loss: 0.3296 - accuracy: 0.8742 - val_loss: 0.3719 - val_accuracy: 0.8510
#
# Epoch 00011: val_loss did not improve from 0.29213
# Epoch 12/30
# 536/536 [==============================] - 960s 2s/step - loss: 0.3070 - accuracy: 0.8753 - val_loss: 0.3298 - val_accuracy: 0.8590
#
# Epoch 00012: val_loss did not improve from 0.29213
# Epoch 13/30
# 536/536 [==============================] - 949s 2s/step - loss: 0.3466 - accuracy: 0.8759 - val_loss: 0.2931 - val_accuracy: 0.8830
#
# Epoch 00013: val_loss did not improve from 0.29213
# Epoch 14/30
# 536/536 [==============================] - 950s 2s/step - loss: 0.3093 - accuracy: 0.8733 - val_loss: 0.3005 - val_accuracy: 0.8720
#
# Epoch 00014: val_loss did not improve from 0.29213
# Epoch 15/30
# 536/536 [==============================] - 951s 2s/step - loss: 0.3086 - accuracy: 0.8741 - val_loss: 0.3227 - val_accuracy: 0.8680
#
# Epoch 00015: val_loss did not improve from 0.29213
# Epoch 16/30
# 536/536 [==============================] - 953s 2s/step - loss: 0.3143 - accuracy: 0.8735 - val_loss: 0.3112 - val_accuracy: 0.8650
#
# Epoch 00016: val_loss did not improve from 0.29213
# Epoch 17/30
# 536/536 [==============================] - 952s 2s/step - loss: 0.3099 - accuracy: 0.8731 - val_loss: 0.3012 - val_accuracy: 0.8790
#
# Epoch 00017: val_loss did not improve from 0.29213
# Epoch 18/30
# 536/536 [==============================] - 951s 2s/step - loss: 0.3029 - accuracy: 0.8764 - val_loss: 0.2919 - val_accuracy: 0.8840
#
# Epoch 00018: val_loss improved from 0.29213 to 0.29193, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 19/30
# 536/536 [==============================] - 949s 2s/step - loss: 0.2933 - accuracy: 0.8782 - val_loss: 0.3051 - val_accuracy: 0.8790
#
# Epoch 00019: val_loss did not improve from 0.29193
# Epoch 20/30
# 536/536 [==============================] - 953s 2s/step - loss: 0.2885 - accuracy: 0.8810 - val_loss: 0.3156 - val_accuracy: 0.8780
#
# Epoch 00020: val_loss did not improve from 0.29193
# Epoch 21/30
# 536/536 [==============================] - 960s 2s/step - loss: 0.2928 - accuracy: 0.8806 - val_loss: 0.2813 - val_accuracy: 0.8760
#
# Epoch 00021: val_loss improved from 0.29193 to 0.28127, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 22/30
# 536/536 [==============================] - 950s 2s/step - loss: 0.3138 - accuracy: 0.8807 - val_loss: 0.2755 - val_accuracy: 0.8960
#
# Epoch 00022: val_loss improved from 0.28127 to 0.27551, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 23/30
# 536/536 [==============================] - 952s 2s/step - loss: 0.2931 - accuracy: 0.8813 - val_loss: 0.2862 - val_accuracy: 0.8790
#
# Epoch 00023: val_loss did not improve from 0.27551
# Epoch 24/30
# 536/536 [==============================] - 951s 2s/step - loss: 0.2894 - accuracy: 0.8822 - val_loss: 0.2763 - val_accuracy: 0.8890
#
# Epoch 00024: val_loss did not improve from 0.27551
# Epoch 25/30
# 536/536 [==============================] - 958s 2s/step - loss: 0.3084 - accuracy: 0.8789 - val_loss: 0.3013 - val_accuracy: 0.8840
#
# Epoch 00025: val_loss did not improve from 0.27551
# Epoch 26/30
# 536/536 [==============================] - 952s 2s/step - loss: 0.2920 - accuracy: 0.8793 - val_loss: 0.2695 - val_accuracy: 0.8910
#
# Epoch 00026: val_loss improved from 0.27551 to 0.26947, saving model to breast_histopathology_baseline_NOAUG.hdf5
# Epoch 27/30
# 536/536 [==============================] - 951s 2s/step - loss: 0.3281 - accuracy: 0.8815 - val_loss: 0.2911 - val_accuracy: 0.8830
#
# Epoch 00027: val_loss did not improve from 0.26947
# Epoch 28/30
# 536/536 [==============================] - 951s 2s/step - loss: 0.3032 - accuracy: 0.8831 - val_loss: 0.9790 - val_accuracy: 0.8650
#
# Epoch 00028: val_loss did not improve from 0.26947
# Epoch 29/30
# 536/536 [==============================] - 952s 2s/step - loss: 0.3118 - accuracy: 0.8811 - val_loss: 0.2883 - val_accuracy: 0.8910
#
# Epoch 00029: val_loss did not improve from 0.26947
# Epoch 30/30
# 536/536 [==============================] - 954s 2s/step - loss: 0.3389 - accuracy: 0.8823 - val_loss: 0.3170 - val_accuracy: 0.8670
#
# Epoch 00030: val_loss did not improve from 0.26947

# %%
import matplotlib.pyplot as plt
training_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epoch_count = range(1, 31)

plt.figure()
plt.plot(epoch_count, training_acc, 'r--')
plt.plot(epoch_count, val_acc, 'b-')
plt.legend(['Training Acc', 'Validation Acc'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.savefig("../vgg19_baseline_model_NOAUG.png")
plt.show()

# %%
# Load Weights of the Baseline Model
model.load_weights('breast_histopathology_baseline_NOAUG.hdf5')

# %%
# Test Predictions
preds = model.predict_generator(test_batches_bench, steps=len(df_test), verbose=1)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# 10000/10000 [==============================] - 83s 8ms/step

# %%
# Accuracy using the baseline model
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
# Take the highest probability scores to get index of predictions for test images
y_pred = np.argmax(preds, axis=1)

# Get labels of test images
y_true = test_batches_bench.classes

# Evaluate
print(f'Accuracy: {accuracy_score(y_true, y_pred):1.3f}%')

print(f'Balanced Accuracy: {balanced_accuracy_score(y_true, y_pred):1.3f}%')
# Balanced accuracy is calculated as the average of the proportion correct of each class individually

f = open("../testOutput_NoAUG.txt", "w")
f.write(f'Accuracy: {accuracy_score(y_true, y_pred):1.3f}%\n')
f.write(f'Balanced Accuracy: {balanced_accuracy_score(y_true, y_pred):1.3f}%\n')
f.close()
# Out:
# Accuracy: 0.888%
# Balanced Accuracy: 0.842%

# %%
# Confusion matrix for the baseline model
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_true, y_pred)
plt.imshow(conf_matrix, interpolation='nearest', cmap='viridis')
plt.title('Confusion matrix')
plt.colorbar()
tick_marks = np.arange(len(['negative', 'positive']))
plt.xticks(tick_marks, ['negative', 'positive'])
plt.yticks(tick_marks, ['negative', 'positive'])
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.savefig("../vgg19-baseline-model-confusion-matrix-NoAUG.png")

# %%
confusionmatrix = confusion_matrix(y_true, y_pred)

f = open("../testOutput_NoAUG.txt", "a")
f.write(f'Confusion matrix: {confusionmatrix}\n')
f.close()

confusionmatrix
# Out:
# array([[6794,  367],
#        [ 749, 2090]])

# %%
from sklearn.metrics import classification_report
report = classification_report(y_true=y_true, y_pred=y_pred, target_names=['negative', 'positive'])

f = open("../testOutput_NoAUG.txt", "a")
f.write(f'REPORT:\n {report}\n')
f.close()

print(report)
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.95      0.92      7161
#     positive       0.85      0.74      0.79      2839
#
#     accuracy                           0.89     10000
#    macro avg       0.88      0.84      0.86     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
x, y = valid_batches_bench.next()

for i in range(1,10):
  
  image = x[i]
  label = y[i]
#   f = open("../testOutput_NoAUG.txt", "a")
  if np.argmax(label, axis=0) == 0:
      print('IDC negative')
#       f.write(f'IDC negative\n')
  if np.argmax(label, axis=0) == 1:
    print('IDC positive')
#     f.write(f'IDC positive\n')

#   print(image.shape)
#   prob = model.predict(image)
#   for a in prob:
#     for b in a:
#       print(f'Predicted Negative Probability: {(b*100):1.2f}%')
#       print(f'Predicted Positive Probability: {(1-b)*100:1.2f}%')
#       f.write(f'Predicted Negative Probability: {(b*100):1.2f}%\n')
#       f.write(f'Predicted Positive Probability: {(1-b)*100:1.2f}%\n')
#       break

  plt.imshow(image)
#   f.write(image)
  plt.show()
#   f.close()
# Out:
# IDC positive
# IDC negative
# IDC negative
# IDC negative
# IDC negative
# IDC negative
# IDC negative
# IDC negative
# IDC negative
